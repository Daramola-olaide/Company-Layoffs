# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as mlb

# %%
df=pd.read_csv('layoff.csv')

# %%
df
# Out:
#                company       location     industry  total_laid_off  \
# 0            Atlassian         Sydney        Other           500.0
# 1             SiriusXM  New York City        Media           475.0
# 2               Alerzo         Ibadan       Retail           400.0
# 3               UpGrad         Mumbai    Education           120.0
# 4                 Loft      Sao Paulo  Real Estate           340.0
# ...                ...            ...          ...             ...
# 2356         Blackbaud     Charleston        Other           500.0
# 2357             Yahoo    SF Bay Area     Consumer          1600.0
# 2358             Hibob       Tel Aviv           HR            70.0
# 2359            Casper  New York City       Retail             NaN
# 2360  Wildlife Studios      Sao Paulo     Consumer           300.0
#
#       percentage_laid_off        date     stage        country  \
# 0                    0.05    3/6/2023  Post-IPO      Australia
# ...

# %%
pd.isnull(df).sum()
# Out:
# company                    0
# location                   0
# industry                   4
# total_laid_off           740
# percentage_laid_off      785
# date                       1
# stage                      6
# country                    0
# funds_raised_millions    209
# dtype: int64

# %% [markdown]
#       How to work on null values

# %% [markdown]
#          1.  modify with the mean value

# %%
df["funds_raised_millions"].fillna(df["funds_raised_millions"].mean());

# %%
df
# Out:
#                company       location     industry  total_laid_off  \
# 0            Atlassian         Sydney        Other           500.0
# 1             SiriusXM  New York City        Media           475.0
# 2               Alerzo         Ibadan       Retail           400.0
# 3               UpGrad         Mumbai    Education           120.0
# 4                 Loft      Sao Paulo  Real Estate           340.0
# ...                ...            ...          ...             ...
# 2356         Blackbaud     Charleston        Other           500.0
# 2357             Yahoo    SF Bay Area     Consumer          1600.0
# 2358             Hibob       Tel Aviv           HR            70.0
# 2359            Casper  New York City       Retail             NaN
# 2360  Wildlife Studios      Sao Paulo     Consumer           300.0
#
#       percentage_laid_off        date     stage        country  \
# 0                    0.05    3/6/2023  Post-IPO      Australia
# ...

# %% [markdown]
#           2.  Drop all null values

# %%
laid=df.dropna()

# %%
laid
# Out:
#                company       location        industry  total_laid_off  \
# 0            Atlassian         Sydney           Other           500.0
# 1             SiriusXM  New York City           Media           475.0
# 4                 Loft      Sao Paulo     Real Estate           340.0
# 5        Embark Trucks    SF Bay Area  Transportation           230.0
# 11             Zscaler    SF Bay Area        Security           177.0
# ...                ...            ...             ...             ...
# 2353       Panda Squad    SF Bay Area        Consumer             6.0
# 2354     Tamara Mellon    Los Angeles          Retail            20.0
# 2357             Yahoo    SF Bay Area        Consumer          1600.0
# 2358             Hibob       Tel Aviv              HR            70.0
# 2360  Wildlife Studios      Sao Paulo        Consumer           300.0
#
#       percentage_laid_off        date     stage        country  \
# ...

# %% [markdown]
#     Reset index after removing null values

# %%
df3=laid.reset_index(drop=True)

# %%
df3
# Out:
#                company       location        industry  total_laid_off  \
# 0            Atlassian         Sydney           Other           500.0
# 1             SiriusXM  New York City           Media           475.0
# 2                 Loft      Sao Paulo     Real Estate           340.0
# 3        Embark Trucks    SF Bay Area  Transportation           230.0
# 4              Zscaler    SF Bay Area        Security           177.0
# ...                ...            ...             ...             ...
# 1087       Panda Squad    SF Bay Area        Consumer             6.0
# 1088     Tamara Mellon    Los Angeles          Retail            20.0
# 1089             Yahoo    SF Bay Area        Consumer          1600.0
# 1090             Hibob       Tel Aviv              HR            70.0
# 1091  Wildlife Studios      Sao Paulo        Consumer           300.0
#
#       percentage_laid_off        date     stage        country  \
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2356    False
# 2357     True
# 2358     True
# 2359     True
# 2360     True
# Length: 2361, dtype: bool

# %% [markdown]
#     To remove all duplicates

# %%
df.drop_duplicates()
# Out:
#             company        location        industry  total_laid_off  \
# 0         Atlassian          Sydney           Other           500.0
# 1          SiriusXM   New York City           Media           475.0
# 2            Alerzo          Ibadan          Retail           400.0
# 3            UpGrad          Mumbai       Education           120.0
# 4              Loft       Sao Paulo     Real Estate           340.0
# ...             ...             ...             ...             ...
# 2352   HopSkipDrive     Los Angeles  Transportation             8.0
# 2353    Panda Squad     SF Bay Area        Consumer             6.0
# 2354  Tamara Mellon     Los Angeles          Retail            20.0
# 2355       EasyPost  Salt Lake City       Logistics            75.0
# 2356      Blackbaud      Charleston           Other           500.0
#
#       percentage_laid_off       date     stage        country  \
# 0                    0.05   3/6/2023  Post-IPO      Australia
# ...

# %%
df.dtypes
# Out:
# company                   object
# location                  object
# industry                  object
# total_laid_off           float64
# percentage_laid_off      float64
# date                      object
# stage                     object
# country                   object
# funds_raised_millions    float64
# dtype: object

# %%
laid1=laid['date']=pd.to_datetime(laid['date'])  ### convert date from object to datetime
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1272\1356609420.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laid1=laid['date']=pd.to_datetime(laid['date'])  ### convert date from object to datetime

# %%
laid1
# Out:
# 0      2023-03-06
# 1      2023-03-06
# 4      2023-03-03
# 5      2023-03-03
# 11     2023-03-02
#           ...
# 2353   2020-03-13
# 2354   2020-03-12
# 2357   2023-02-09
# 2358   2020-03-30
# 2360   2022-11-28
# Name: date, Length: 1092, dtype: datetime64[ns]

# %%
laid1['year']=laid['date'].dt.year            ###  extract year from the date

# %%
laid1
# Out:
# 0                                     2023-03-06 00:00:00
# 1                                     2023-03-06 00:00:00
# 4                                     2023-03-03 00:00:00
# 5                                     2023-03-03 00:00:00
# 11                                    2023-03-02 00:00:00
#                               ...
# 2354                                  2020-03-12 00:00:00
# 2357                                  2023-02-09 00:00:00
# 2358                                  2020-03-30 00:00:00
# 2360                                  2022-11-28 00:00:00
# year    0       2023
# 1       2023
# 4       2023
# 5      ...
# Name: date, Length: 1093, dtype: object

# %% [markdown]
#     To reorder columns

# %%
 df2=df[['company','location','country','industry','total_laid_off','percentage_laid_off','funds_raised_millions','stage','date']]

# %%
df2.head()
# Out:
#      company       location        country     industry  total_laid_off  \
# 0  Atlassian         Sydney      Australia        Other           500.0
# 1   SiriusXM  New York City  United States        Media           475.0
# 2     Alerzo         Ibadan        Nigeria       Retail           400.0
# 3     UpGrad         Mumbai          India    Education           120.0
# 4       Loft      Sao Paulo         Brazil  Real Estate           340.0
#
#    percentage_laid_off  funds_raised_millions     stage      date
# 0                 0.05                  210.0  Post-IPO  3/6/2023
# 1                 0.08                  525.0  Post-IPO  3/6/2023
# 2                  NaN                   16.0  Series B  3/6/2023
# 3                  NaN                  631.0   Unknown  3/6/2023
# 4                 0.15                  788.0   Unknown  3/3/2023

# %%
df.dtypes
# Out:
# company                   object
# location                  object
# industry                  object
# total_laid_off           float64
# percentage_laid_off      float64
# date                      object
# stage                     object
# country                   object
# funds_raised_millions    float64
# dtype: object

# %% [markdown]
#           Exploratory Data Analysis

# %% [markdown]
#     find the total laid off

# %%
df3=df["total_laid_off"].sum()

# %%
df3
# Out:
# 386379.0

# %% [markdown]
#     total funds raised in millions

# %%
df3=df["funds_raised_millions"].sum()

# %%
df3
# Out:
# 1769921.2955

# %% [markdown]
#      Laid off per country

# %%
laid.groupby('country')['total_laid_off'].agg(['sum','mean','count']).sort_values('sum', ascending=False)
# Out:
#                            sum         mean  count
# country
# United States         206277.0   290.530986    710
# India                  20140.0   300.597015     67
# Sweden                 10582.0  1058.200000     10
# Brazil                  7043.0   153.108696     46
# Germany                 6369.0   167.605263     38
# United Kingdom          6093.0   184.636364     33
# Canada                  4795.0    81.271186     59
# Singapore               3795.0   210.833333     18
# Indonesia               2721.0   340.125000      8
# Israel                  2457.0    66.405405     37
# United States.          1575.0   787.500000      2
# Australia               1447.0    90.437500     16
# United Arab Emirates     995.0   248.750000      4
# Nigeria                  970.0   242.500000      4
# China                    755.0   251.666667      3
# Hong Kong                730.0   243.333333      3
# France                   643.0   214.333333      3
# ...

# %%
laid.groupby(laid1['year'])['total_laid_off'].mean()
# Out:
# date
# 2020    183.825301
# 2021    499.230769
# 2022    218.861160
# 2023    499.926966
# Name: total_laid_off, dtype: float64

# %%
ax=sb.countplot(x='stage',data=df)
sb.set(rc={'figure.figsize' :(25,10)})
for viewvalue in ax.containers:
    ax.bar_label(viewvalue)

# %%
laid1['year'].value_counts().plot(kind='pie',figsize=(12,6),shadow=True, autopct='%1.2f%%')
mlb.title('Total laid off per year')
mlb.show()

# %%
df['industry'].value_counts()
# Out:
# industry
# Finance            284
# Retail             195
# Healthcare         183
# Transportation     148
# Food               141
# Marketing          139
# Other              129
# Consumer           118
# Real Estate        117
# Crypto              99
# Media               95
# Education           93
# Data                79
# Security            74
# HR                  66
# Travel              66
# Support             43
# Infrastructure      43
# Logistics           42
# Sales               37
# Product             35
# Fitness             31
# Recruiting          28
# Hardware            17
# Construction        16
# Legal               13
# Energy              12
# Aerospace            6
# Fin-Tech             3
# Manufacturing        2
# Crypto Currency      2
# CryptoCurrency       1
# Name: count, dtype: int64

# %%
df['industry'].value_counts().plot(kind='bar',figsize=(12,6))
mlb.xlabel('Industry')
mlb.ylabel('Total_laid_off')
mlb.title('Total laid off per industry')
mlb.legend()
